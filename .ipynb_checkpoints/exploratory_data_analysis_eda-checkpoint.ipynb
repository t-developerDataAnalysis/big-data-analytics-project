# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Attribute correlations

# %%
#correlations of the data 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#backwards elimination with python statsmodels.api
import pandas as pd
import statsmodels.api as sm

# %%
### Correlation heat map
df  = pd.read_csv('datasets/data_cleaned_for_eda.csv',  sep=",",low_memory=False)

df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17464 entries, 0 to 17463
# Data columns (total 110 columns):
#  #    Column                  Dtype
# ---   ------                  -----
#  0    Unnamed: 0              int64
#  1    Time                    int64
#  2    LocID                   int64
#  3    SortOrder               int64
#  4    Notes                   float64
#  5    ISO3_code               object
#  6    ISO2_code               object
#  7    SDMX_code               float64
#  8    LocTypeID               int64
#  9    LocTypeName             object
#  10   ParentID                int64
#  11   Location                object
#  12   VarID                   int64
#  13   Variant                 object
#  14   TPopulation1Jan         float64
#  15   TPopulation1July        float64
#  16   TPopulationMale1July    float64
#  17   TPopulationFemale1July  float64
#  18   PopDensity              float64
#  19   PopSexRatio             float64
#  20   MedianAgePop            float64
#  21   NatChange               float64
#  22   NatChangeRT             float64
#  23   PopChange               float64
#  24   PopGrowthRate           float64
#  25   DoublingTime            float64
#  26   Births                  float64
#  27   Births1519              float64
#  28   CBR                     float64
#  29   TFR                     float64
#  30   NRR                     float64
#  31   MAC                     float64
#  32   SRB                     float64
#  33   Deaths                  float64
#  34   DeathsMale              float64
#  35   DeathsFemale            float64
#  36   CDR                     float64
#  37   LEx                     float64
#  38   LExMale                 float64
#  39   LExFemale               float64
#  40   LE15                    float64
#  41   LE15Male                float64
#  42   LE15Female              float64
#  43   LE65                    float64
#  44   LE65Male                float64
#  45   LE65Female              float64
#  46   LE80                    float64
#  47   LE80Male                float64
#  48   LE80Female              float64
#  49   InfantDeaths            float64
#  50   IMR                     float64
#  51   LBsurvivingAge1         float64
#  52   Under5Deaths            float64
#  53   Q5                      float64
#  54   Q0040                   float64
#  55   Q0040Male               float64
#  56   Q0040Female             float64
#  57   Q0060                   float64
#  58   Q0060Male               float64
#  59   Q0060Female             float64
#  60   Q1550                   float64
#  61   Q1550Male               float64
#  62   Q1550Female             float64
#  63   Q1560                   float64
#  64   Q1560Male               float64
#  65   Q1560Female             float64
#  66   NetMigrations           float64
#  67   CNMR                    float64
#  68   00_04_male              float64
#  69   00_04_female            float64
#  70   05_09_male              float64
#  71   05_09_female            float64
#  72   10_14_male              float64
#  73   10_14_female            float64
#  74   15_19_male              float64
#  75   15_19_female            float64
#  76   20_24_male              float64
#  77   20_24_female            float64
#  78   25_29_male              float64
#  79   25_29_female            float64
#  80   30_34_male              float64
#  81   30_34_female            float64
#  82   35_39_male              float64
#  83   35_39_female            float64
#  84   40_44_male              float64
#  85   40_44_female            float64
#  86   45_49_male              float64
#  87   45_49_female            float64
#  88   50_54_male              float64
#  89   50_54_female            float64
#  90   55_59_male              float64
#  91   55_59_female            float64
#  92   60_64_male              float64
#  93   60_64_female            float64
#  94   65_69_male              float64
#  95   65_69_female            float64
#  96   70_74_male              float64
#  97   70_74_female            float64
#  98   75_79_male              float64
#  99   75_79_female            float64
#  100  80_84_male              float64
#  101  80_84_female            float64
#  102  85_89_male              float64
#  103  85_89_female            float64
#  104  90_94_male              float64
#  105  90_94_female            float64
#  106  95_99_male              float64
#  107  95_99_female            float64
#  108  100_male                float64
#  109  100_female              float64
# dtypes: float64(98), int64(7), object(5)
# memory usage: 14.7+ MB

# %%
#Deleting first attribute garbage generated
df = df.iloc[:, 1:]

#show the dataframe
df.head()
# Out:
#    Time  LocID  SortOrder  Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0  1950    108         29    NaN       BDI        BI      108.0          4
# 1  1951    108         29    NaN       BDI        BI      108.0          4
# 2  1952    108         29    NaN       BDI        BI      108.0          4
# 3  1953    108         29    NaN       BDI        BI      108.0          4
# 4  1954    108         29    NaN       BDI        BI      108.0          4
#
#     LocTypeName  ParentID  ... 80_84_male  80_84_female 85_89_male  \
# 0  Country/Area       910  ...      1.756         2.368      0.465
# 1  Country/Area       910  ...      1.878         2.562      0.456
# 2  Country/Area       910  ...      2.014         2.788      0.443
# 3  Country/Area       910  ...      2.140         3.008      0.442
# 4  Country/Area       910  ...      2.237         3.191      0.462
#
#    85_89_female  90_94_male  90_94_female  95_99_male  95_99_female  100_male  \
# 0         0.754       0.068         0.147       0.005         0.018       0.0
# 1         0.741       0.057         0.143       0.002         0.010       0.0
# 2         0.723       0.052         0.143       0.001         0.009       0.0
# 3         0.722       0.051         0.145       0.001         0.009       0.0
# 4         0.756       0.052         0.145       0.001         0.006       0.0
#
#    100_female
# 0       0.002
# 1       0.001
# 2       0.001
# 3       0.001
# 4       0.000
#
# [5 rows x 109 columns]

# %% [markdown]
# ## Heatmap of correlations

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr(numeric_only = True)

# Generate a heatmap to visualize the correlations
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Attribute Correlations')
plt.show()

# %% [markdown]
# ## Correlation table

# %%
cormat = df.corr(numeric_only = True)
round(cormat,2)
# Out:
#               Time  LocID  SortOrder  Notes  SDMX_code  LocTypeID  ParentID  \
# Time          1.00  -0.00      -0.00  -0.00      -0.00        NaN      0.00
# LocID        -0.00   1.00       0.01   0.02       1.00        NaN     -0.03
# SortOrder    -0.00   0.01       1.00   0.49       0.01        NaN     -0.17
# Notes        -0.00   0.02       0.49   1.00       0.02        NaN      0.41
# SDMX_code    -0.00   1.00       0.01   0.02       1.00        NaN     -0.03
# ...            ...    ...        ...    ...        ...        ...       ...
# 90_94_female  0.15   0.01       0.02   0.05       0.01        NaN      0.01
# 95_99_male    0.15   0.03       0.03   0.10       0.03        NaN      0.04
# 95_99_female  0.15   0.02       0.03   0.09       0.02        NaN     -0.00
# 100_male      0.14   0.04       0.04   0.13       0.04        NaN      0.04
# 100_female    0.14   0.04       0.03   0.12       0.04        NaN     -0.01
#
#               VarID  TPopulation1Jan  TPopulation1July  ...  80_84_male  \
# Time            NaN             0.08              0.07  ...        0.13
# LocID           NaN            -0.05             -0.05  ...       -0.02
# SortOrder       NaN            -0.08             -0.08  ...       -0.02
# Notes           NaN            -0.08             -0.08  ...       -0.01
# SDMX_code       NaN            -0.05             -0.05  ...       -0.02
# ...             ...              ...               ...  ...         ...
# 90_94_female    NaN             0.62              0.62  ...        0.92
# 95_99_male      NaN             0.51              0.50  ...        0.77
# 95_99_female    NaN             0.46              0.46  ...        0.78
# 100_male        NaN             0.36              0.36  ...        0.56
# 100_female      NaN             0.30              0.30  ...        0.60
#
#               80_84_female  85_89_male  85_89_female  90_94_male  \
# Time                  0.13        0.14          0.14        0.15
# LocID                -0.01       -0.01         -0.00        0.00
# SortOrder            -0.01       -0.00          0.00        0.01
# Notes                -0.00        0.02          0.02        0.05
# SDMX_code            -0.01       -0.01         -0.00        0.00
# ...                    ...         ...           ...         ...
# 90_94_female          0.92        0.96          0.97        0.97
# 95_99_male            0.75        0.85          0.82        0.94
# 95_99_female          0.78        0.86          0.87        0.93
# 100_male              0.55        0.65          0.62        0.78
# 100_female            0.60        0.69          0.70        0.81
#
#               90_94_female  95_99_male  95_99_female  100_male  100_female
# Time                  0.15        0.15          0.15      0.14        0.14
# LocID                 0.01        0.03          0.02      0.04        0.04
# SortOrder             0.02        0.03          0.03      0.04        0.03
# Notes                 0.05        0.10          0.09      0.13        0.12
# SDMX_code             0.01        0.03          0.02      0.04        0.04
# ...                    ...         ...           ...       ...         ...
# 90_94_female          1.00        0.90          0.95      0.72        0.82
# 95_99_male            0.90        1.00          0.94      0.93        0.91
# 95_99_female          0.95        0.94          1.00      0.82        0.95
# 100_male              0.72        0.93          0.82      1.00        0.88
# 100_female            0.82        0.91          0.95      0.88        1.00
#
# [104 rows x 104 columns]

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr(numeric_only = True)

# Iterate over the columns and find the most correlated attribute for each
correlation_percentage = {}
for column in correlation_matrix.columns:
    max_corr = correlation_matrix[column].drop(column).max()
    attribute = correlation_matrix[column].drop(column).idxmax()
    correlation_percentage[column] = f"{max_corr * 100:.2f}% correlated with '{attribute}'"

# Display the correlation percentages
for attribute, correlation in correlation_percentage.items():
    print(f"{attribute}: {correlation}")
# Out:
# Time: 57.95% correlated with 'LE65Female'
# LocID: 100.00% correlated with 'SDMX_code'
# SortOrder: 48.65% correlated with 'Notes'
# Notes: 48.65% correlated with 'SortOrder'
# SDMX_code: 100.00% correlated with 'LocID'
# LocTypeID: nan% correlated with 'nan'
# ParentID: 41.35% correlated with 'Notes'
# VarID: nan% correlated with 'nan'
# TPopulation1Jan: 100.00% correlated with 'TPopulation1July'
# TPopulation1July: 100.00% correlated with 'TPopulation1Jan'
# TPopulationMale1July: 99.99% correlated with 'TPopulation1July'
# TPopulationFemale1July: 99.99% correlated with 'TPopulation1Jan'
# PopDensity: 23.27% correlated with 'MedianAgePop'
# PopSexRatio: 28.51% correlated with 'PopGrowthRate'
# MedianAgePop: 77.61% correlated with 'LE65Female'
# NatChange: 99.49% correlated with 'PopChange'
# NatChangeRT: 92.75% correlated with 'NRR'
# PopChange: 99.49% correlated with 'NatChange'
# PopGrowthRate: 82.14% correlated with 'CNMR'
# DoublingTime: 9.75% correlated with '40_44_female'
# Births: 99.95% correlated with 'LBsurvivingAge1'
# Births1519: 89.01% correlated with 'InfantDeaths'
# CBR: 97.72% correlated with 'TFR'
# TFR: 97.72% correlated with 'CBR'
# NRR: 93.88% correlated with 'TFR'
# MAC: 39.87% correlated with 'TFR'
# SRB: 32.93% correlated with 'LE15Female'
# Deaths: 99.92% correlated with 'DeathsMale'
# DeathsMale: 99.92% correlated with 'Deaths'
# DeathsFemale: 99.90% correlated with 'Deaths'
# CDR: 88.26% correlated with 'Q5'
# LEx: 99.58% correlated with 'LExMale'
# LExMale: 99.58% correlated with 'LEx'
# LExFemale: 99.56% correlated with 'LEx'
# LE15: 98.44% correlated with 'LE15Male'
# LE15Male: 98.44% correlated with 'LE15'
# LE15Female: 98.40% correlated with 'LE15'
# LE65: 98.96% correlated with 'LE65Female'
# LE65Male: 97.22% correlated with 'LE65'
# LE65Female: 98.96% correlated with 'LE65'
# LE80: 99.36% correlated with 'LE80Female'
# LE80Male: 96.37% correlated with 'LE80'
# LE80Female: 99.36% correlated with 'LE80'
# InfantDeaths: 99.64% correlated with 'Under5Deaths'
# IMR: 98.49% correlated with 'Q5'
# LBsurvivingAge1: 99.95% correlated with 'Births'
# Under5Deaths: 99.64% correlated with 'InfantDeaths'
# Q5: 98.49% correlated with 'IMR'
# Q0040: 99.61% correlated with 'Q0040Male'
# Q0040Male: 99.61% correlated with 'Q0040'
# Q0040Female: 99.45% correlated with 'Q0040'
# Q0060: 99.21% correlated with 'Q0060Male'
# Q0060Male: 99.21% correlated with 'Q0060'
# Q0060Female: 99.08% correlated with 'Q0060'
# Q1550: 98.79% correlated with 'Q1560'
# Q1550Male: 98.53% correlated with 'Q1550'
# Q1550Female: 99.18% correlated with 'Q1560Female'
# Q1560: 98.79% correlated with 'Q1550'
# Q1560Male: 98.44% correlated with 'Q1560'
# Q1560Female: 99.18% correlated with 'Q1550Female'
# NetMigrations: 30.54% correlated with 'CNMR'
# CNMR: 82.14% correlated with 'PopGrowthRate'
# 00_04_male: 99.95% correlated with '00_04_female'
# 00_04_female: 99.95% correlated with '00_04_male'
# 05_09_male: 99.95% correlated with '05_09_female'
# 05_09_female: 99.95% correlated with '05_09_male'
# 10_14_male: 99.95% correlated with '10_14_female'
# 10_14_female: 99.95% correlated with '10_14_male'
# 15_19_male: 99.95% correlated with '15_19_female'
# 15_19_female: 99.95% correlated with '15_19_male'
# 20_24_male: 99.95% correlated with '20_24_female'
# 20_24_female: 99.95% correlated with '20_24_male'
# 25_29_male: 99.94% correlated with '25_29_female'
# 25_29_female: 99.94% correlated with '25_29_male'
# 30_34_male: 99.94% correlated with '30_34_female'
# 30_34_female: 99.94% correlated with '30_34_male'
# 35_39_male: 99.93% correlated with '35_39_female'
# 35_39_female: 99.93% correlated with '35_39_male'
# 40_44_male: 99.91% correlated with '40_44_female'
# 40_44_female: 99.91% correlated with '40_44_male'
# 45_49_male: 99.90% correlated with '45_49_female'
# 45_49_female: 99.90% correlated with '45_49_male'
# 50_54_male: 99.87% correlated with '50_54_female'
# 50_54_female: 99.87% correlated with '50_54_male'
# 55_59_male: 99.81% correlated with '55_59_female'
# 55_59_female: 99.81% correlated with '55_59_male'
# 60_64_male: 99.71% correlated with '60_64_female'
# 60_64_female: 99.71% correlated with '60_64_male'
# 65_69_male: 99.55% correlated with '65_69_female'
# 65_69_female: 99.55% correlated with '65_69_male'
# 70_74_male: 99.45% correlated with '65_69_male'
# 70_74_female: 99.27% correlated with '70_74_male'
# 75_79_male: 99.28% correlated with '70_74_male'
# 75_79_female: 99.07% correlated with '70_74_female'
# 80_84_male: 99.01% correlated with '75_79_male'
# 80_84_female: 98.81% correlated with '75_79_female'
# 85_89_male: 98.46% correlated with '80_84_male'
# 85_89_female: 98.22% correlated with '85_89_male'
# 90_94_male: 97.26% correlated with '90_94_female'
# 90_94_female: 97.37% correlated with '85_89_female'
# 95_99_male: 94.48% correlated with '95_99_female'
# 95_99_female: 95.30% correlated with '90_94_female'
# 100_male: 93.15% correlated with '95_99_male'
# 100_female: 94.95% correlated with '95_99_female'
